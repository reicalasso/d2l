# %% [markdown]
# ## 1.3.4 Reinforcement Learning

# %% [markdown]
# Reinforcement Learning:
# Reinforcement learning studies how an agent interacts with an environment by taking actions and receiving rewards over time. At each step, the agent observes the environment, selects an action according to a policy, and receives a reward. The goal is to learn a policy that maximizes long-term reward.
#
# RL handles problems where feedback is delayed, partial, or indirect, leading to challenges such as credit assignment, partial observability, and the exploration–exploitation tradeoff. Special cases include Markov decision processes (MDPs), contextual bandits, and multi-armed bandits.
#
# ![image.png](attachment:image.png)
#
# - Supervised learning is told the answer.
# - Reinforcement learning discovers the answer by acting.
